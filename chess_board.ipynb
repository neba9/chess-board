# %%
print('hello')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# grid = np.ones((8, 8, 3))
grid = np.zeros((8, 8, 3))
# grid
# help(np.ones)

# %%
# help(plt.imshow)
# to change the colore the cell value 0:0 assign RGB color 
# grid[0][0] = (1, 1, 1)
# grid[1][1] = (1, 1, 1)
# grid[2][2] = (1, 1, 1)
# white = (1,1,1)
# for i in range(8):
#     grid[i][i] = white
# plt.imshow(grid)

# %%
# class chess_board:
#     def __init__(self):
#         self.grid = np.zeros((8, 8, 3))

#         self.black = (0,0,0)
#         self.white = (1,1,1)

#         for row in range(len(self.grid)):
#             for col in range(len(self.grid[row])):
#                 if row % 2 and col % 2:
#                     self.grid[row][col] = self.white
#                 elif not row % 2 and not col % 2:
#                     self.grid[row][col] = self.white
#                 else:
#                     continue
#     def __str__(self):
#         return f'{self.grid.tolist()}'
    
#     def add_red(self, row, col):
#         self.grid[row][col] = (1, 2, 0)
#         # pass

#     def add_blue(self, row, col):
#         self.grid[row][col] = (0, 1, 1)
#         # pass

#     def render(self):
#         plt.imshow(self.grid)
    
#     def is_under_attack(self):
#         pass

# %%
class chess_board:
    def __init__(self):
        self.grid = np.zeros((8, 8, 3))

        self.black = (0,0,0)
        self.white = (1,1,1)

        for row in range(len(self.grid)):
            for col in range(len(self.grid[row])):
                if row % 2:
                    if col % 2:
                        self.grid[row][col] = self.white
                    elif self.grid[row][col] = self.black
                elif 
                    if col % 2:
                        self.grid[row][col] = self.black
                    elif self.grid[row][col] = self.white

                # if row % 2 and col % 2:
                #     self.grid[row][col] = self.white
                # elif not row % 2 and not col % 2:
                #     self.grid[row][col] = self.white
                # else:
                #     continue
    def __str__(self):
        return f'{self.grid.tolist()}'
    
    def add_red(self, row, col):
        self.grid[row][col] = (1, 2, 0)
        # pass

    def add_blue(self, row, col):
        self.grid[row][col] = (0, 1, 1)
        # pass

    def render(self):
        plt.imshow(self.grid)
    
    def is_under_attack(self):
        pass

# %%
board_img = chess_board()

# %%
board_img.render()

# %%
board_img.add_red(2,3)
board_img.render()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
board_img.add_blue(6, 6)
board_img.render()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
